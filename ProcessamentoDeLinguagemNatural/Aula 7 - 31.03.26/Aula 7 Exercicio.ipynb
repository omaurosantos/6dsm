# %% [markdown]
# # Notebook Jupyter – Exercícios de PLN (Aluno)
# Resolva os exercícios abaixo. Complete as células de código onde indicado.

# %% [markdown]
# ## Exercício 1 – Bag-of-Words e TF-IDF

# %%
# Complete o código
docs = [
    'o produto é excelente e chegou rápido',
    'o produto veio com defeito',
    'entrega rápida e produto de qualidade'
]

# Gere a matriz Bag-of-Words

# Gere a matriz TF-IDF

# %% [markdown]
# ## Exercício 2 – Análise Sintática com spaCy

# %%
# Complete o código
import spacy
# carregar modelo pt_core_news_sm
texto = 'A empresa comprou a startup por 5 milhões.'

# identificar sujeito, verbo e objeto

# %% [markdown]
# ## Exercício 3 – Descoberta de Tópicos

# %%
# Complete o código
docs_topicos = [
    'python e machine learning em ciência de dados',
    'redes neurais e inteligência artificial',
    'futebol campeonato gol atacante',
    'time venceu campeonato nacional'
]

# aplicar TF-IDF
# usar KMeans com 2 clusters
# mostrar cluster de cada documento
